# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib as plt
import matplotlib.pyplot as plt

# %%
#load dataset
from keras.datasets import mnist
mnist = tf.keras.datasets.mnist
(x_tr, y_tr),(x_ts, y_ts) = mnist.load_data()

# %%
#mnist = tf.keras.datasets.mnist
#(x_tr, y_tr),(x_ts, y_ts) = mnist.load data()
#(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
fig = plt.figure()
for i in range(10):
    plt.imshow(x_tr[i], cmap = plt.cm.binary)#cm = color map
    plt.title("Digit: {}".format(y_tr[i]))
    plt.show()

# %%
#normalize data 
print("x_train shape", x_tr.shape)
print("y_train shape", y_tr.shape)
print("x_test shape", x_ts.shape)
print("y_test shape", y_ts.shape)

x_tr = x_tr.astype('float32') / 255
x_ts = x_ts.astype('float32') / 255
# Out:
# x_train shape (60000, 28, 28)
# y_train shape (60000,)
# x_test shape (10000, 28, 28)
# y_test shape (10000,)

# %%
unique, counts = np.unique(y_ts, return_counts = True)
print("Test labels: ", dict(zip(unique, counts)))

unique, counts = np.unique(y_tr, return_counts = True)
print("Train labels: ", dict(zip(unique, counts)))
# Out:
# Test labels:  {0: 980, 1: 1135, 2: 1032, 3: 1010, 4: 982, 5: 892, 6: 958, 7: 1028, 8: 974, 9: 1009}
# Train labels:  {0: 5923, 1: 6742, 2: 5958, 3: 6131, 4: 5842, 5: 5421, 6: 5918, 7: 6265, 8: 5851, 9: 5949}

# %%
#25 mnist digits from train set
indexes = np.random.randint(0, x_tr.shape[0], size=25)
images = x_tr[indexes]
labels = y_tr[indexes]

# %%
#implementing sigmoid and gradient descent

def sigmoid(a):
    return 1/(1+np.exp(-a))

def gradient_descent(theta, x_tr, y_tr, lmbda):
    m = len(y_tr)
    temp = sigmoid(np.dot(x_tr, theta)) - y_tr
    temp = np.dot(temp.T, x_tr).T / m + theta * lmbda / m
    temp[0] = temp[0] - theta[0] * lmbda / m
    return temp
